# %%
# Q 3.1

masses = [1.9891e+30, 1.8986e+27, 
          5.6846e+26, 1.0243e+26, 8.6810e+25,
          5.9736e+24, 4.8685e+24, 6.4185e+23, 
          3.3022e+23, 7.349e+22, 1.25e+22]
small = []

i = 0
for i in range(len(masses)):
    if masses[i] <= masses[-2]:
        small.append(masses[i])

print(small)

new = masses[-5:]
print(new)

Sum = sum(new)
N = len(new)
avg = Sum / N
print(avg)
# Out:
# [7.349e+22, 1.25e+22]
# [4.8685e+24, 6.4185e+23, 3.3022e+23, 7.349e+22, 1.25e+22]
# 1.1853119999999999e+24

# %%
# Q 3.2

import numpy as np
from scipy.constants import G

masses = [1.9891e+30, 1.8986e+27, 5.6846e+26, 
          1.0243e+26, 8.6810e+25, 5.9736e+24, 
          4.8685e+24, 6.4185e+23, 3.3022e+23, 
          7.349e+22, 1.25e22]
radii  = [696340, 71492, 60268, 24764, 
          25559, 6378.1, 6051.8, 3396.2, 
          2439.7, 1738.1, 1195]
names  = ['Sun', 'Jupiter', 'Saturn', 'Neptune', 
          'Uranus', 'Earth', 'Venus', 'Mars', 
          'Mercury', 'Moon', 'Pluto']
planets = {}

for i in range(len(masses)):
    M = masses[i]
    r = radii[i]
    v = np.sqrt(2 * G * M / (r * 1000))
    print(f"The escape velocity of {names[i]} is {v:.2f} m/s.")
    planets[names[i]] = v

print(planets)
# Out:
# The escape velocity of (the) Sun is 617497.92 m/s.
# The escape velocity of (the) Jupiter is 59539.59 m/s.
# The escape velocity of (the) Saturn is 35483.33 m/s.
# The escape velocity of (the) Neptune is 23497.47 m/s.
# The escape velocity of (the) Uranus is 21292.70 m/s.
# The escape velocity of (the) Earth is 11181.25 m/s.
# The escape velocity of (the) Venus is 10362.71 m/s.
# The escape velocity of (the) Mars is 5022.71 m/s.
# The escape velocity of (the) Mercury is 4250.61 m/s.
# The escape velocity of (the) Moon is 2375.72 m/s.
# The escape velocity of (the) Pluto is 1181.65 m/s.
# {'Sun': np.float64(617497.9167791922), 'Jupiter': np.float64(59539.59478320213), 'Saturn': np.float64(35483.334491201014), 'Neptune': np.float64(23497.46700006528), 'Uranus': np.float64(21292.703606794767), 'Earth': np.float64(11181.24765336743), 'Venus': np.float64(10362.705674286997), 'Mars': np.float64(5022.708842483838), 'Mercury': np.float64(4250.610719256492), 'Moon': np.float64(2375.7164429821673), 'Pluto': np.float64(1181.6501475181674)}

# %%
# Q 3.6

Sum = []
for x in range(1,1000):
    l = 1 / x**2
    Sum.append(l)
    Value = sum(Sum)
    if x == 10:
        print(Value)
    elif x == 100:
        print(Value)
    elif x == 500:
        print(Value)
    elif x == 999:
        print(Value)
# Out:
# 1.5497677311665408
# 1.634983900184893
# 1.6429360655148941
# 1.6439335666815598

# %%
# Q 3.7
import numpy as np

def angs(d,D):
    d = float(input('Size of object:'))
    D = float(input('Distance to object:'))
    delta = 2 * np.arctan(d / (2 * D))
    return delta

angs(d,D)
print(f'The angular size of the object is {delta} arcsec.')
# Out:
# Size of object: 2
# Distance to object: 5
# The angular size of the object is 0.19933730498232408 arcsec.

# %%
# Q 3.10
from math import pi

r = float(input('Radius:'))
h = float(input('Height:'))

def cylinder(r, h):
    A = 2 * pi * r**2 + 2 * pi * r * h
    V = pi * r**2 * h
    s = f'A = {A}, V = {V}'
    return s

print(f'The area and volume are: {cylinder(r,h)}')
# Out:
# Radius: 5
# Height: 2
# The area and volume are: A = 219.9114857512855, V = 157.07963267948966

# %%
# Q 3.14 (pending)
import numpy as np

x = [1,10**2,2*10,5.1*20,-4,4.45**2]
X = np.array(x)

Xmin = X.min()
Xmax = X.max()

l = np.linspace(1, 2.5, 20)

r = np.arange(1,2.5,.1)

x = np.random.normal(0,5,10000)
i = np.where(x>5)
print(i)

rev = x[::-1]
print(rev[:10])

z = np.zeros(10)
print(z)
c = np.repeat(1+0j,10)
# Out:
# (array([   1,    3,   29, ..., 9991, 9994, 9996], shape=(1584,)),)
# [-13.34186996   2.36539119   0.75834801   6.46261475  -5.43097515
#    9.56017301  -3.20013206  -1.7047892    9.09302646  -4.33385794]

# %%
# Q 3.17 (pending)

import numpy as np

a = np.random.normal(0,1,1000)

def stdev(a):
    N = len(a)
    sig = np.sqrt(1/N * sum((a - (1/N * sum(a)))**2))
    return sig

print(f'Manual: {stdev(a)}')
print(f'With NumPy {np.std(a)}')
# Out:
# Manual: 0.9804185429572839
# With NumPy 0.9804185429572841

# %%
# Q 3.18 (pending)
import numpy as np

l = [
    18.49, 2094.75,
    35.48, 2320.87,
    35.48, 1224.9,
    11.34, 872.13,
    7.12 , 432.2,
    9.82 , 751,
    23.66, 1410,
    44  ,  2700,
    66.7,  5292,
    52.4,  2550,
    55  ,  5253,
    25.6,  2419,
    26.19, 2158
]

x = np.array(l[::2])
y = np.array(l[1::2])

avgX = x.mean()
avgY = y.mean()

b = sum((x - avgX) * (y - avgY)) / sum((x - avgX)**2)
a = avgY - b*avgX

print(f'a = {a}, b = {b}')
# Out:
# a = 9.189826687586446, b = 71.38295626595355

# %% [markdown]
# $y = a + bx \rightarrow y = 9.19 + 71.38 \; x$

# %%
# Q 3.22 (pending)
import matplotlib.pyplot as plt
import numpy as np

c = []
for x in range(-5,6):
    c.append(np.cosh(x))

plt.scatter(range(-5,6), c, marker='+', s=80, label='x-points')
plt.plot(range(-5,6), c, color='grey', label='x-approx')
plt.title('$cosh(x)$')
plt.grid()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend()
plt.show()

C = np.cosh(np.arange(-5,5,.01))

plt.scatter(np.arange(-5,5,.01), C, marker='+', s=80, label='x-points')
plt.plot(np.arange(-5,5,.01), C, color='grey', label='x-approx')
plt.title('$cosh(x)$')
plt.grid()
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend()
plt.show()
