# %% [markdown]
# Answers for Week 1:
# * Name: Adria Valmana Perez
# * Username: avalmana
# * Student s-number: S6217338
# * Group: AS5

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 #Processed on Jupyter Hub

# %%
x = 6
x *= x-1
print(x)
# Out:
# 30

# %%
from scipy.constants import h, c

f = 2.42e28
l = 1 / f
E = h * c / l
print(E)
# Out:
# 4807.198974300408

# %%
from scipy.constants import G

m_earth = 7.342e22
m_moon = 5.9722e24
r = 385000600

F = G * m_earth * m_moon / r**2
print(F, "N")
# Out:
# 1.974384051807571e+20 N

# %% [markdown]
# Q 1.15:
# 1. /home/localuser3/Downloads
# 2. /home/localuser3/Downloads and /home/localuser3

# %% [markdown]
# Q 1.16:
# ~/Desktop

# %% [markdown]
# Q 1.19:
# The function of * is to replace any and all characters, including none.
# 1. It lists all files structured as any character(s), then a series of numbers, then any character(s), followed by . and any combination of c and/or o.
# 2. \[ is basically 'from' and \] is 'to'
# 3. The latter will show files as above, before the dot, but only those that end with '.co'.
