# %%
import numpy as np
from numpy import linalg as la

from scipy.interpolate import 
import matplotlib.pyplot as plt

# %%
# Q 7.1
A = np.array([1, 2, 3, 0, -4, 1, 0, 3, -1]).reshape(3, 3)
print(la.det(A))
# Out:
# 1.0

# %%
b = np.array([2, 2, -1])
Ainv = la.inv(A)
xyz = Ainv@b
print(f'[x, y, z] = {xyz}')
# Out:
# [x, y, z] = [10. -1. -2.]

# %%
prod = A@A.T
if prod.flatten().all == np.identity(3).flatten().all:
    print('A is orthogonal')
else:
    print('A is not orthogonal')
# Out:
# A is not orthogonal

# %%
lamda, v = la.eig(A)
print(lamda)
# Out:
# [ 1.         -4.79128785 -0.20871215]

# %%
# Q 7.3
def Ey(beta):
    beta = np.deg2rad(beta)
    E_y = np.array([np.cos(beta), 0, -np.sin(beta), 0, 1, 0, np.sin(beta), 0, np.cos(beta)]).reshape(3,3)
    return E_y

def Ez(gamma):
    gamma = np.deg2rad(gamma)
    E_z = np.array([np.cos(gamma), np.sin(gamma), 0, -np.sin(gamma), np.cos(gamma), 0, 0, 0, 1]).reshape(3,3)
    return E_z

E = Ez(180-123) @ Ey(90-27.4) @ Ez(192.25)
print(E)
# Out:
# [[-0.06698874 -0.87275577 -0.48353891]
#  [ 0.49272847 -0.45034696  0.74458463]
#  [-0.86760081 -0.1883746   0.46019978]]

# %%
print(la.eigvals(E))
# Rot matrix if last value is 1
# Out:
# [-0.52856796+0.84889099j -0.52856796-0.84889099j  1.        +0.j        ]

# %%
ra = 192.25
dec = 27.4

def r(ra, dec):
    ra = np.deg2rad(ra)
    dec = np.deg2rad(dec)
    x = np.cos(dec) * np.cos(ra)
    y = np.cos(dec) * np.sin(ra)
    z = np.sin(dec)
    return np.array([x, y, z]).reshape(3,1)

v = r(ra, dec)
print(v)
print(la.norm(v))

print('\n', E@v)
# Out:
# [[-0.86760081]
#  [-0.1883746 ]
#  [ 0.46019978]]
# 1.0
#
#  [[2.77555756e-17]
#  [5.55111512e-17]
#  [1.00000000e+00]]

# %%
# Q 7.5
a = np.array([1.2, 2.0, 3.1, 4.4, 4.9, 5.8, 6.9, 8.0, 9.1, 9.9]).reshape(5,2)
b = np.array([0.3, 0.5, 0.7, 0.8, 1.3, 1.6, 2.0, 2.3, 2.9, 3.0]).reshape(10,1)

for i in a:
    

curve = CubicSpline(x,y)

x = la.solve(a, b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[107], line 5
#       2 a = np.array([1.2, 2.0, 3.1, 4.4, 4.9, 5.8, 6.9, 8.0, 9.1, 9.9]).reshape(5,2)
#       3 b = np.array([0.3, 0.5, 0.7, 0.8, 1.3, 1.6, 2.0, 2.3, 2.9, 3.0]).reshape(1,10)
# ----> 5 curve = CubicSpline(x,y)
#       7 x = la.solve(a, b)
#
# NameError: name 'CubicSpline' is not defined

# %%
plt.scatter(x, y)
plt.
plt.show()
